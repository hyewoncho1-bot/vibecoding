# %% [markdown]
# # week2/week2_조혜원

# %%
# [예시] 프롬프트: "파이썬으로 점수 리스트 평균/최대/최소 계산해줘"

def stats_bad(scores):
    avg = sum(scores) / len(scores)
    return avg, max(scores), min(scores)

print(stats_bad([80, 90, 100]))
# Out:
# (90.0, 100, 80)

# %%
# [예시] 구조화된 프롬프트 기반 코드

def stats_good(scores):
    """
    scores: 정수 또는 실수로 이루어진 리스트
    return: 다음 정보를 담은 딕셔너리
      - average: 평균
      - max: 최대값
      - min: 최소값
      - count: 점수 개수
    """
    if len(scores) == 0:
        raise ValueError("점수 리스트가 비어 있습니다. 하나 이상의 점수를 입력하세요.")

    avg = sum(scores) / len(scores)
    return {
        "average": avg,
        "max": max(scores),
        "min": min(scores),
        "count": len(scores),
    }

print(stats_good([80, 90, 100]))
# Out:
# {'average': 90.0, 'max': 100, 'min': 80, 'count': 3}

# %%
# [실습용] 버그가 있는 코드 예시

def divide_list(numbers, divisor):
    """
    numbers 리스트의 각 원소를 divisor로 나눈 결과 리스트를 반환한다.
    """
    result = []
    for n in numbers:
        result.append(n / divisor)
    return result

print(divide_list([10, 20, 30], 0))  # 일부러 에러 발생
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_958/2763712184.py in <cell line: 0>()
#      10     return result
#      11
# ---> 12 print(divide_list([10, 20, 30], 0))  # 일부러 에러 발생
#
# /tmp/ipykernel_958/2763712184.py in divide_list(numbers, divisor)
#       7     result = []
#       8     for n in numbers:
# ----> 9         result.append(n / divisor)
#      10     return result
#      11
#
# ZeroDivisionError: division by zero

# %%
# @title AI prompt cell

import ipywidgets as widgets
from IPython.display import display, HTML, Markdown,clear_output
from google.colab import ai

dropdown = widgets.Dropdown(
    options=[],
    layout={'width': 'auto'}
)

def update_model_list(new_options):
    dropdown.options = new_options
update_model_list(ai.list_models())

text_input = widgets.Textarea(
    placeholder='Ask me anything....',
    layout={'width': 'auto', 'height': '100px'},
)

button = widgets.Button(
    description='Submit Text',
    disabled=False,
    tooltip='Click to submit the text',
    icon='check'
)

output_area = widgets.Output(
     layout={'width': 'auto', 'max_height': '300px','overflow_y': 'scroll'}
)

def on_button_clicked(b):
    with output_area:
        output_area.clear_output(wait=False)
        accumulated_content = ""
        for new_chunk in ai.generate_text(prompt=text_input.value, model_name=dropdown.value, stream=True):
            if new_chunk is None:
                continue
            accumulated_content += new_chunk
            clear_output(wait=True)
            display(Markdown(accumulated_content))

button.on_click(on_button_clicked)
vbox = widgets.GridBox([dropdown, text_input, button, output_area])

display(HTML("""
<style>
.widget-dropdown select {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
.widget-textarea textarea {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
</style>
"""))
display(vbox)
# Out:
# <style>
# .widget-dropdown select {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# .widget-textarea textarea {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# </style>
# GridBox(children=(Dropdown(layout=Layout(width='auto'), options=('google/gemini-2.5-flash', 'google/gemini-2.5…

# %%
# @title AI prompt cell

import ipywidgets as widgets
from IPython.display import display, HTML, Markdown,clear_output
from google.colab import ai

dropdown = widgets.Dropdown(
    options=[],
    layout={'width': 'auto'}
)

def update_model_list(new_options):
    dropdown.options = new_options
update_model_list(ai.list_models())

text_input = widgets.Textarea(
    placeholder='Ask me anything....',
    layout={'width': 'auto', 'height': '100px'},
)

button = widgets.Button(
    description='Submit Text',
    disabled=False,
    tooltip='Click to submit the text',
    icon='check'
)

output_area = widgets.Output(
     layout={'width': 'auto', 'max_height': '300px','overflow_y': 'scroll'}
)

def on_button_clicked(b):
    with output_area:
        output_area.clear_output(wait=False)
        accumulated_content = ""
        for new_chunk in ai.generate_text(prompt=text_input.value, model_name=dropdown.value, stream=True):
            if new_chunk is None:
                continue
            accumulated_content += new_chunk
            clear_output(wait=True)
            display(Markdown(accumulated_content))

button.on_click(on_button_clicked)
vbox = widgets.GridBox([dropdown, text_input, button, output_area])

display(HTML("""
<style>
.widget-dropdown select {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
.widget-textarea textarea {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
</style>
"""))
display(vbox)
# Out:
# <style>
# .widget-dropdown select {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# .widget-textarea textarea {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# </style>
# GridBox(children=(Dropdown(layout=Layout(width='auto'), options=('google/gemini-2.5-flash', 'google/gemini-2.5…

# %% [markdown]
# V1일 때는 단순히 기능만 구현됐는데, V3에서 에러 케이스를 명시하니까 AI가 복잡한 예외 처리 코드까지 스스로 짜주는 게 신기했다. 내가 규칙을 정해줄수록 코드를 수정하는 번거로움이 줄어든다는 걸 깨달았다.
